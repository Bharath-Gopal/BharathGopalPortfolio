# %% [markdown]
# Obesity has been an issue in the United States over the last few years.
# Our project aims at answering the question: 'Does Income have an effect on the prevanlence of Obesity in the United States?'

# %% [markdown]
# Our dataset consists of data regarding the prevalence of obesity in men and women for the years 2009 and 2011 as well as the average state incomes for the same years.

# %% [markdown]
# Our datasets come from 3 main sources.
# 1. The state-wise income for the year 2011, obtained from Wikipedia.
# 2. The prevalence of obesity in men and women for the years 2009 and 2011 from healthdata.org
# 3. The state-wise income for the year 2009, obtained from https://nces.ed.gov/programs/digest/d10/tables/dt10_025.asp

# %%
#importing pandas
import pandas as pd

# %%
#reading the table
URL = "https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_income"
tables = pd.read_html(URL)
print(tables[1])
# Out:
#    State Rank States and Washington, D.C.     2019     2018     2017     2016  \
# 0         NaN               United States  $65,712  $63,179  $60,336  $57,617
# 1           –            Washington, D.C.  $92,266  $85,203  $82,372  $75,506
# 2           1                    Maryland  $86,738  $83,242  $80,776  $78,945
# 3           2               Massachusetts  $85,843  $79,835  $77,385  $75,297
# 4           3                  New Jersey  $85,751  $81,740  $80,088  $76,126
# 5           4                      Hawaii  $83,102  $80,212  $77,765  $74,511
# 6           5                  California  $80,440  $75,277  $71,805  $67,739
# 7           6                 Connecticut  $78,833  $76,348  $74,168  $73,433
# 8           7                  Washington  $78,687  $74,073  $70,979  $67,106
# 9           8               New Hampshire  $77,933  $74,991  $73,381  $70,936
# 10          9                    Colorado  $77,127  $71,953  $69,117  $65,685
# ...

# %% [markdown]
# Assigning the dataframe

# %%
df = tables[1]

# %%
df
# Out:
#    State Rank States and Washington, D.C.     2019     2018     2017     2016  \
# 0         NaN               United States  $65,712  $63,179  $60,336  $57,617
# 1           –            Washington, D.C.  $92,266  $85,203  $82,372  $75,506
# 2           1                    Maryland  $86,738  $83,242  $80,776  $78,945
# 3           2               Massachusetts  $85,843  $79,835  $77,385  $75,297
# 4           3                  New Jersey  $85,751  $81,740  $80,088  $76,126
# 5           4                      Hawaii  $83,102  $80,212  $77,765  $74,511
# 6           5                  California  $80,440  $75,277  $71,805  $67,739
# 7           6                 Connecticut  $78,833  $76,348  $74,168  $73,433
# 8           7                  Washington  $78,687  $74,073  $70,979  $67,106
# 9           8               New Hampshire  $77,933  $74,991  $73,381  $70,936
# 10          9                    Colorado  $77,127  $71,953  $69,117  $65,685
# ...

# %%
state_income = df

# %%
state_income
# Out:
#    State Rank States and Washington, D.C.     2019     2018     2017     2016  \
# 0         NaN               United States  $65,712  $63,179  $60,336  $57,617
# 1           –            Washington, D.C.  $92,266  $85,203  $82,372  $75,506
# 2           1                    Maryland  $86,738  $83,242  $80,776  $78,945
# 3           2               Massachusetts  $85,843  $79,835  $77,385  $75,297
# 4           3                  New Jersey  $85,751  $81,740  $80,088  $76,126
# 5           4                      Hawaii  $83,102  $80,212  $77,765  $74,511
# 6           5                  California  $80,440  $75,277  $71,805  $67,739
# 7           6                 Connecticut  $78,833  $76,348  $74,168  $73,433
# 8           7                  Washington  $78,687  $74,073  $70,979  $67,106
# 9           8               New Hampshire  $77,933  $74,991  $73,381  $70,936
# 10          9                    Colorado  $77,127  $71,953  $69,117  $65,685
# ...

# %% [markdown]
# Reading obesity data

# %%
df1 = pd.read_excel('IHME_county_data_LifeExpectancy_Obesity_PhysicalActivity_NATIONAL (1).xlsx',sheet_name='Obesity')

# %%
df1
# Out:
#               State      County  Male obesity prevalence, 2001 (%)  \
# 0     United States         NaN                               26.1
# 1           Alabama         NaN                               29.7
# 2           Alabama     Autauga                               30.7
# 3           Alabama     Baldwin                               27.8
# 4           Alabama     Barbour                               32.3
# ...             ...         ...                                ...
# 3189        Wyoming  Sweetwater                               26.6
# 3190        Wyoming       Teton                               17.8
# 3191        Wyoming       Uinta                               24.1
# 3192        Wyoming    Washakie                               23.5
# 3193        Wyoming      Weston                               27.0
#
#       Female obesity prevalence, 2001 (%)  Male obesity prevalence, 2009 (%)  \
# 0                                    28.7                               32.8
# ...

# %% [markdown]
# Reading state income for the year 2009

# %%
URL = "https://nces.ed.gov/programs/digest/d10/tables/dt10_025.asp"
tables = pd.read_html(URL,header=None)
print(tables[3])
# Out:
#    [In constant 2009 dollars]                                               \
#                         State    19901    20002     2005              2006
#                             1        2        3        4      4.1        5
# 0               United States  $50,200  $54,058  $50,800    ($70)  $51,500
# 1                     Alabama    39412    43942    40500    (350)    41300
# 2                      Alaska    69160    66387    61800  (1,210)    63200
# 3                     Arizona    45997    52210    48700    (430)    50300
# 4                    Arkansas    35320    41428    38500    (400)    38900
# ..                        ...      ...      ...      ...      ...      ...
# 56                   Virginia    55664    60087    59600    (360)    59900
# 57                 Washington    52082    58927    54100    (430)    55900
# 58              West Virginia    34732    38227    36800    (530)    37300
# ...

# %%
df2 = tables[3]

# %%
df2
# Out:
#    [In constant 2009 dollars]                                               \
#                         State    19901    20002     2005              2006
#                             1        2        3        4      4.1        5
# 0               United States  $50,200  $54,058  $50,800    ($70)  $51,500
# 1                     Alabama    39412    43942    40500    (350)    41300
# 2                      Alaska    69160    66387    61800  (1,210)    63200
# 3                     Arizona    45997    52210    48700    (430)    50300
# 4                    Arkansas    35320    41428    38500    (400)    38900
# ..                        ...      ...      ...      ...      ...      ...
# 56                   Virginia    55664    60087    59600    (360)    59900
# 57                 Washington    52082    58927    54100    (430)    55900
# 58              West Virginia    34732    38227    36800    (530)    37300
# ...

# %%
obesity = df1

# %%
obesity
# Out:
#               State      County  Male obesity prevalence, 2001 (%)  \
# 0     United States         NaN                               26.1
# 1           Alabama         NaN                               29.7
# 2           Alabama     Autauga                               30.7
# 3           Alabama     Baldwin                               27.8
# 4           Alabama     Barbour                               32.3
# ...             ...         ...                                ...
# 3189        Wyoming  Sweetwater                               26.6
# 3190        Wyoming       Teton                               17.8
# 3191        Wyoming       Uinta                               24.1
# 3192        Wyoming    Washakie                               23.5
# 3193        Wyoming      Weston                               27.0
#
#       Female obesity prevalence, 2001 (%)  Male obesity prevalence, 2009 (%)  \
# 0                                    28.7                               32.8
# ...

# %%
income_2009 = df2

# %%
income_2009
# Out:
#    [In constant 2009 dollars]                                               \
#                         State    19901    20002     2005              2006
#                             1        2        3        4      4.1        5
# 0               United States  $50,200  $54,058  $50,800    ($70)  $51,500
# 1                     Alabama    39412    43942    40500    (350)    41300
# 2                      Alaska    69160    66387    61800  (1,210)    63200
# 3                     Arizona    45997    52210    48700    (430)    50300
# 4                    Arkansas    35320    41428    38500    (400)    38900
# ..                        ...      ...      ...      ...      ...      ...
# 56                   Virginia    55664    60087    59600    (360)    59900
# 57                 Washington    52082    58927    54100    (430)    55900
# 58              West Virginia    34732    38227    36800    (530)    37300
# ...

# %%
state_income
# Out:
#    State Rank States and Washington, D.C.     2019     2018     2017     2016  \
# 0         NaN               United States  $65,712  $63,179  $60,336  $57,617
# 1           –            Washington, D.C.  $92,266  $85,203  $82,372  $75,506
# 2           1                    Maryland  $86,738  $83,242  $80,776  $78,945
# 3           2               Massachusetts  $85,843  $79,835  $77,385  $75,297
# 4           3                  New Jersey  $85,751  $81,740  $80,088  $76,126
# 5           4                      Hawaii  $83,102  $80,212  $77,765  $74,511
# 6           5                  California  $80,440  $75,277  $71,805  $67,739
# 7           6                 Connecticut  $78,833  $76,348  $74,168  $73,433
# 8           7                  Washington  $78,687  $74,073  $70,979  $67,106
# 9           8               New Hampshire  $77,933  $74,991  $73,381  $70,936
# 10          9                    Colorado  $77,127  $71,953  $69,117  $65,685
# ...

# %% [markdown]
# Dropping the unnecessary columns

# %%
temp = state_income.drop(columns=['State Rank','2019','2018','2017','2016','2015','2014','2013','2012','2010'])

# %%
temp = temp.iloc[: , :-1]

# %% [markdown]
# Sorting the data frame according to state names

# %%
temp = temp.sort_values(by='States and Washington, D.C.')

# %%
temp.drop(0,inplace=True)

# %%
temp.reset_index(inplace=True)

# %%
temp.columns
# Out:
# Index(['index', 'States and Washington, D.C.', '2011'], dtype='object')

# %%
temp.drop(['index'],axis=1,inplace=True)

# %%
temp
# Out:
#    States and Washington, D.C.     2011
# 0                      Alabama  $41,415
# 1                       Alaska  $67,825
# 2                      Arizona  $46,709
# 3                     Arkansas  $38,758
# 4                   California  $57,287
# 5                     Colorado  $55,387
# 6                  Connecticut  $65,753
# 7                     Delaware  $58,814
# 8                      Florida  $44,299
# 9                      Georgia  $46,007
# 10                      Hawaii  $61,821
# 11                       Idaho  $43,341
# 12                    Illinois  $53,234
# 13                     Indiana  $46,438
# 14                        Iowa  $49,427
# 15                      Kansas  $48,964
# 16                    Kentucky  $41,141
# 17                   Louisiana  $41,734
# 18                       Maine  $46,033
# 19                    Maryland  $70,004
# 20               Massachusetts  $62,859
# 21                    Michigan  $45,981
# ...

# %% [markdown]
# Checking for null values

# %%
temp.isna().sum()
# Out:
# States and Washington, D.C.    0
# 2011                           0
# dtype: int64

# %%
income_2009
# Out:
#    [In constant 2009 dollars]                                               \
#                         State    19901    20002     2005              2006
#                             1        2        3        4      4.1        5
# 0               United States  $50,200  $54,058  $50,800    ($70)  $51,500
# 1                     Alabama    39412    43942    40500    (350)    41300
# 2                      Alaska    69160    66387    61800  (1,210)    63200
# 3                     Arizona    45997    52210    48700    (430)    50300
# 4                    Arkansas    35320    41428    38500    (400)    38900
# ..                        ...      ...      ...      ...      ...      ...
# 56                   Virginia    55664    60087    59600    (360)    59900
# 57                 Washington    52082    58927    54100    (430)    55900
# 58              West Virginia    34732    38227    36800    (530)    37300
# ...

# %% [markdown]
# Dropping multilevel attributes from the column name

# %%
income_2009.columns = income_2009.columns.droplevel()

# %%
income_2009.columns = income_2009.columns.droplevel()

# %%
income_2009
# Out:
#                 1        2        3        4      4.1        5    5.1  \
# 0   United States  $50,200  $54,058  $50,800    ($70)  $51,500  ($50)
# 1         Alabama    39412    43942    40500    (350)    41300  (330)
# 2          Alaska    69160    66387    61800  (1,210)    63200  (930)
# 3         Arizona    45997    52210    48700    (430)    50300  (280)
# 4        Arkansas    35320    41428    38500    (400)    38900  (320)
# ..            ...      ...      ...      ...      ...      ...    ...
# 56       Virginia    55664    60087    59600    (360)    59900  (300)
# 57     Washington    52082    58927    54100    (430)    55900  (310)
# 58  West Virginia    34732    38227    36800    (530)    37300  (400)
# 59      Wisconsin    49174    56372    51800    (260)    51900  (280)
# 60        Wyoming    45256    48778    50800  (1,010)    50500  (960)
#
#           6      6.1        7      7.1        8      8.1
# 0   $52,500    ($50)  $51,800    ($40)  $50,200    ($40)
# ...

# %% [markdown]
# Dropping the unnecessary columns

# %%
income_2009 = income_2009.drop(columns=['2','3','4','4.1','5','5.1','6','6.1','7','7.1','8.1'])

# %%
income_2009
# Out:
#                 1        8
# 0   United States  $50,200
# 1         Alabama    40500
# 2          Alaska    67000
# 3         Arizona    48700
# 4        Arkansas    37800
# ..            ...      ...
# 56       Virginia    59300
# 57     Washington    56500
# 58  West Virginia    37400
# 59      Wisconsin    50000
# 60        Wyoming    52700
#
# [61 rows x 2 columns]

# %% [markdown]
# Renaming the columns

# %%
income_2009.columns=['state', '2009 income']

# %%
income_2009
# Out:
#             state 2009 income
# 0   United States     $50,200
# 1         Alabama       40500
# 2          Alaska       67000
# 3         Arizona       48700
# 4        Arkansas       37800
# ..            ...         ...
# 56       Virginia       59300
# 57     Washington       56500
# 58  West Virginia       37400
# 59      Wisconsin       50000
# 60        Wyoming       52700
#
# [61 rows x 2 columns]

# %%
income_2009.drop(0,axis=0,inplace=True)

# %%
income_2009.shape
# Out:
# (60, 2)

# %% [markdown]
# Checking for null values

# %%
income_2009.isna().sum()
# Out:
# state          9
# 2009 income    9
# dtype: int64

# %% [markdown]
# Removing the Null Values

# %%
income_2009 = income_2009.dropna()

# %%
income_2009.shape
# Out:
# (51, 2)

# %%
income_2009.reset_index(inplace=True)

# %%
income_2009.columns
# Out:
# Index(['index', 'state', '2009 income'], dtype='object')

# %%
income_2009.drop('index',axis=1,inplace=True)
# Out:
# C:\Users\Bharath\AppData\Local\Temp\ipykernel_18928\480794556.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_2009.drop('index',axis=1,inplace=True)

# %%
income_2009
# Out:
#                    state 2009 income
# 0                Alabama       40500
# 1                 Alaska       67000
# 2                Arizona       48700
# 3               Arkansas       37800
# 4             California       58900
# 5               Colorado       55400
# 6            Connecticut       67000
# 7               Delaware       56900
# 8   District of Columbia       59300
# 9                Florida       44700
# 10               Georgia       47600
# 11                Hawaii       64100
# 12                 Idaho       44900
# 13              Illinois       54000
# 14               Indiana       45400
# 15                  Iowa       48000
# 16                Kansas       47800
# 17              Kentucky       40100
# 18             Louisiana       42500
# 19                 Maine       45700
# 20              Maryland       69300
# 21         Massachusetts       64100
# 22              Michigan       45300
# 23             Minnesota       55600
# ...

# %% [markdown]
# Renaming 'District of Columbia' to 'Washington, D.C'

# %%
income_2009['state'][8] = 'Washington, D.C.'
# Out:
# C:\Users\Bharath\AppData\Local\Temp\ipykernel_18928\4182966259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_2009['state'][8] = 'Washington, D.C.'

# %% [markdown]
# Merging two dataframes containing the incomes for 2009 and 2011

# %%
temp = temp.merge(income_2009, left_on='States and Washington, D.C.', right_on='state')

# %%
temp.drop('state',axis=1,inplace=True)

# %%
temp.columns
# Out:
# Index(['States and Washington, D.C.', '2011', '2009 income'], dtype='object')

# %% [markdown]
# Renaming the columns

# %%
temp.columns = ['States', 'Income 2011', 'Income 2009']

# %%
temp
# Out:
#               States Income 2011 Income 2009
# 0            Alabama     $41,415       40500
# 1             Alaska     $67,825       67000
# 2            Arizona     $46,709       48700
# 3           Arkansas     $38,758       37800
# 4         California     $57,287       58900
# 5           Colorado     $55,387       55400
# 6        Connecticut     $65,753       67000
# 7           Delaware     $58,814       56900
# 8            Florida     $44,299       44700
# 9            Georgia     $46,007       47600
# 10            Hawaii     $61,821       64100
# 11             Idaho     $43,341       44900
# 12          Illinois     $53,234       54000
# 13           Indiana     $46,438       45400
# 14              Iowa     $49,427       48000
# 15            Kansas     $48,964       47800
# 16          Kentucky     $41,141       40100
# 17         Louisiana     $41,734       42500
# 18             Maine     $46,033       45700
# 19          Maryland     $70,004       69300
# ...

# %% [markdown]
# Checking the datatypes

# %%
temp.dtypes
# Out:
# States         object
# Income 2011    object
# Income 2009    object
# dtype: object

# %% [markdown]
# Removing the '$' symbol from column 'Income 2011'

# %%
temp['Income 2011'] = temp['Income 2011'].str[1:]

# %%
temp
# Out:
#               States Income 2011 Income 2009
# 0            Alabama      41,415       40500
# 1             Alaska      67,825       67000
# 2            Arizona      46,709       48700
# 3           Arkansas      38,758       37800
# 4         California      57,287       58900
# 5           Colorado      55,387       55400
# 6        Connecticut      65,753       67000
# 7           Delaware      58,814       56900
# 8            Florida      44,299       44700
# 9            Georgia      46,007       47600
# 10            Hawaii      61,821       64100
# 11             Idaho      43,341       44900
# 12          Illinois      53,234       54000
# 13           Indiana      46,438       45400
# 14              Iowa      49,427       48000
# 15            Kansas      48,964       47800
# 16          Kentucky      41,141       40100
# 17         Louisiana      41,734       42500
# 18             Maine      46,033       45700
# 19          Maryland      70,004       69300
# ...

# %%
temp.dtypes
# Out:
# States         object
# Income 2011    object
# Income 2009    object
# dtype: object

# %% [markdown]
# Removing the ',' from column 'Income 2011'

# %%
temp['Income 2011']=temp['Income 2011'].str.replace(',','')

# %%
temp
# Out:
#               States Income 2011 Income 2009
# 0            Alabama       41415       40500
# 1             Alaska       67825       67000
# 2            Arizona       46709       48700
# 3           Arkansas       38758       37800
# 4         California       57287       58900
# 5           Colorado       55387       55400
# 6        Connecticut       65753       67000
# 7           Delaware       58814       56900
# 8            Florida       44299       44700
# 9            Georgia       46007       47600
# 10            Hawaii       61821       64100
# 11             Idaho       43341       44900
# 12          Illinois       53234       54000
# 13           Indiana       46438       45400
# 14              Iowa       49427       48000
# 15            Kansas       48964       47800
# 16          Kentucky       41141       40100
# 17         Louisiana       41734       42500
# 18             Maine       46033       45700
# 19          Maryland       70004       69300
# ...

# %% [markdown]
# Converting the column 'Income 2011' to type Int

# %%
temp['Income 2011'] = temp['Income 2011'].astype(int)

# %%
temp.dtypes
# Out:
# States         object
# Income 2011     int32
# Income 2009    object
# dtype: object

# %% [markdown]
# Converting the column 'Income 2009' to type Int

# %%
temp['Income 2009'] = temp['Income 2009'].astype(int)

# %%
temp.dtypes
# Out:
# States         object
# Income 2011     int32
# Income 2009     int32
# dtype: object

# %%
obesity
# Out:
#               State      County  Male obesity prevalence, 2001 (%)  \
# 0     United States         NaN                               26.1
# 1           Alabama         NaN                               29.7
# 2           Alabama     Autauga                               30.7
# 3           Alabama     Baldwin                               27.8
# 4           Alabama     Barbour                               32.3
# ...             ...         ...                                ...
# 3189        Wyoming  Sweetwater                               26.6
# 3190        Wyoming       Teton                               17.8
# 3191        Wyoming       Uinta                               24.1
# 3192        Wyoming    Washakie                               23.5
# 3193        Wyoming      Weston                               27.0
#
#       Female obesity prevalence, 2001 (%)  Male obesity prevalence, 2009 (%)  \
# 0                                    28.7                               32.8
# ...

# %% [markdown]
# Dropping unnecessary columns

# %%
obesity = obesity.drop(columns=['Male obesity prevalence, 2001 (%)','Female obesity prevalence, 2001 (%)','Difference in male obesity prevalence, 2001-2009 (percentage points)','Difference in female obesity prevalence, 2001-2009 (percentage points)','Unnamed: 10','*Methodological changes in the 2011 BRFSS may affect comparability between the 2011 estimates and estimates from earlier years'])

# %%
obesity
# Out:
#               State      County  Male obesity prevalence, 2009 (%)  \
# 0     United States         NaN                               32.8
# 1           Alabama         NaN                               36.1
# 2           Alabama     Autauga                               35.9
# 3           Alabama     Baldwin                               32.4
# 4           Alabama     Barbour                               40.3
# ...             ...         ...                                ...
# 3189        Wyoming  Sweetwater                               33.6
# 3190        Wyoming       Teton                               21.1
# 3191        Wyoming       Uinta                               35.2
# 3192        Wyoming    Washakie                               31.3
# 3193        Wyoming      Weston                               35.7
#
#       Female obesity  prevalence, 2009 (%)  \
# 0                                     35.1
# 1                                     41.2
# ...

# %%
temp1 = obesity

# %% [markdown]
# Selecting the rows that contain Null Values in the column 'County'

# %%
temp1 = obesity[obesity['County'].isna()]

# %%
temp1.drop(0,axis=0,inplace=True)
# Out:
# C:\Users\Bharath\AppData\Local\Temp\ipykernel_18928\2143855863.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp1.drop(0,axis=0,inplace=True)

# %%
temp1
# Out:
#                      State County  Male obesity prevalence, 2009 (%)  \
# 1                  Alabama    NaN                               36.1
# 69                  Alaska    NaN                               32.8
# 98                 Arizona    NaN                               31.6
# 114               Arkansas    NaN                               36.1
# 190             California    NaN                               28.7
# 249               Colorado    NaN                               25.8
# 314            Connecticut    NaN                               29.7
# 323               Delaware    NaN                               35.9
# 327   District of Columbia    NaN                               21.6
# 329                Florida    NaN                               33.2
# 397                Georgia    NaN                               33.6
# 557                 Hawaii    NaN                               27.4
# 563                  Idaho    NaN                               32.8
# ...

# %%
temp1.reset_index(inplace=True)

# %%
temp1 = temp1.drop('index',axis=1)

# %%
temp1 = temp1.drop('County',axis=1)

# %%
temp1
# Out:
#                    State  Male obesity prevalence, 2009 (%)  \
# 0                Alabama                               36.1
# 1                 Alaska                               32.8
# 2                Arizona                               31.6
# 3               Arkansas                               36.1
# 4             California                               28.7
# 5               Colorado                               25.8
# 6            Connecticut                               29.7
# 7               Delaware                               35.9
# 8   District of Columbia                               21.6
# 9                Florida                               33.2
# 10               Georgia                               33.6
# 11                Hawaii                               27.4
# 12                 Idaho                               32.8
# 13              Illinois                               32.9
# 14               Indiana                               35.1
# ...

# %%
temp1['State'][8] = 'Washington, D.C.'
# Out:
# C:\Users\Bharath\AppData\Local\Temp\ipykernel_18928\721362540.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp1['State'][8] = 'Washington, D.C.'

# %%
temp1
# Out:
#                State  Male obesity prevalence, 2009 (%)  \
# 0            Alabama                               36.1
# 1             Alaska                               32.8
# 2            Arizona                               31.6
# 3           Arkansas                               36.1
# 4         California                               28.7
# 5           Colorado                               25.8
# 6        Connecticut                               29.7
# 7           Delaware                               35.9
# 8   Washington, D.C.                               21.6
# 9            Florida                               33.2
# 10           Georgia                               33.6
# 11            Hawaii                               27.4
# 12             Idaho                               32.8
# 13          Illinois                               32.9
# 14           Indiana                               35.1
# 15              Iowa                               35.2
# ...

# %% [markdown]
# Sorting the data frame according to the State Name

# %%
temp1 = temp1.sort_values('State')

# %%
temp1.reset_index(inplace=True)

# %%
temp1.columns
# Out:
# Index(['index', 'State', 'Male obesity prevalence, 2009 (%)',
#        'Female obesity  prevalence, 2009 (%)',
#        'Male obesity  prevalence, 2011* (%)',
#        'Female obesity prevalence, 2011* (%)'],
#       dtype='object')

# %%
temp1.drop('index',axis=1,inplace=True)

# %%
temp1
# Out:
#                State  Male obesity prevalence, 2009 (%)  \
# 0            Alabama                               36.1
# 1             Alaska                               32.8
# 2            Arizona                               31.6
# 3           Arkansas                               36.1
# 4         California                               28.7
# 5           Colorado                               25.8
# 6        Connecticut                               29.7
# 7           Delaware                               35.9
# 8            Florida                               33.2
# 9            Georgia                               33.6
# 10            Hawaii                               27.4
# 11             Idaho                               32.8
# 12          Illinois                               32.9
# 13           Indiana                               35.1
# 14              Iowa                               35.2
# 15            Kansas                               34.7
# ...

# %%
obesity = temp1

# %%
obesity
# Out:
#                State  Male obesity prevalence, 2009 (%)  \
# 0            Alabama                               36.1
# 1             Alaska                               32.8
# 2            Arizona                               31.6
# 3           Arkansas                               36.1
# 4         California                               28.7
# 5           Colorado                               25.8
# 6        Connecticut                               29.7
# 7           Delaware                               35.9
# 8            Florida                               33.2
# 9            Georgia                               33.6
# 10            Hawaii                               27.4
# 11             Idaho                               32.8
# 12          Illinois                               32.9
# 13           Indiana                               35.1
# 14              Iowa                               35.2
# 15            Kansas                               34.7
# ...

# %%
df = obesity

# %% [markdown]
# Merging the obesity dataframe with the income dataframe

# %%
df = df.merge(temp, left_on='State', right_on='States')

# %%
df
# Out:
#                State  Male obesity prevalence, 2009 (%)  \
# 0            Alabama                               36.1
# 1             Alaska                               32.8
# 2            Arizona                               31.6
# 3           Arkansas                               36.1
# 4         California                               28.7
# 5           Colorado                               25.8
# 6        Connecticut                               29.7
# 7           Delaware                               35.9
# 8            Florida                               33.2
# 9            Georgia                               33.6
# 10            Hawaii                               27.4
# 11             Idaho                               32.8
# 12          Illinois                               32.9
# 13           Indiana                               35.1
# 14              Iowa                               35.2
# 15            Kansas                               34.7
# ...

# %% [markdown]
# Dropping duplicate column

# %%
df.drop('States',axis=1,inplace=True)

# %%
df
# Out:
#                State  Male obesity prevalence, 2009 (%)  \
# 0            Alabama                               36.1
# 1             Alaska                               32.8
# 2            Arizona                               31.6
# 3           Arkansas                               36.1
# 4         California                               28.7
# 5           Colorado                               25.8
# 6        Connecticut                               29.7
# 7           Delaware                               35.9
# 8            Florida                               33.2
# 9            Georgia                               33.6
# 10            Hawaii                               27.4
# 11             Idaho                               32.8
# 12          Illinois                               32.9
# 13           Indiana                               35.1
# 14              Iowa                               35.2
# 15            Kansas                               34.7
# ...

# %% [markdown]
# Reordering the dataframe

# %%
temp = df[['State','Income 2009','Male obesity prevalence, 2009 (%)','Female obesity  prevalence, 2009 (%)','Income 2011','Male obesity  prevalence, 2011* (%)','Female obesity prevalence, 2011* (%)']]

# %%
temp
# Out:
#                State  Income 2009  Male obesity prevalence, 2009 (%)  \
# 0            Alabama        40500                               36.1
# 1             Alaska        67000                               32.8
# 2            Arizona        48700                               31.6
# 3           Arkansas        37800                               36.1
# 4         California        58900                               28.7
# 5           Colorado        55400                               25.8
# 6        Connecticut        67000                               29.7
# 7           Delaware        56900                               35.9
# 8            Florida        44700                               33.2
# 9            Georgia        47600                               33.6
# 10            Hawaii        64100                               27.4
# 11             Idaho        44900                               32.8
# 12          Illinois        54000                               32.9
# ...

# %%
df = temp

# %% [markdown]
# Calculating the Income increase (%)

# %%
df['Income Increase'] = ((df['Income 2011']-df['Income 2009'])/df['Income 2009'])*100
# Out:
# C:\Users\Bharath\AppData\Local\Temp\ipykernel_18928\3084508474.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Income Increase'] = ((df['Income 2011']-df['Income 2009'])/df['Income 2009'])*100

# %% [markdown]
# Calculating the Male Obesity increase (%)

# %%
df['Male Obesity Increase'] = ((df['Male obesity  prevalence, 2011* (%)']-df['Male obesity prevalence, 2009 (%)'])/df['Male obesity prevalence, 2009 (%)'])*100
# Out:
# C:\Users\Bharath\AppData\Local\Temp\ipykernel_18928\2827226102.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Male Obesity Increase'] = ((df['Male obesity  prevalence, 2011* (%)']-df['Male obesity prevalence, 2009 (%)'])/df['Male obesity prevalence, 2009 (%)'])*100

# %% [markdown]
# Calculating the Female Obesity increase (%)

# %%
df['Female Obesity Increase'] = ((df['Female obesity prevalence, 2011* (%)']-df['Female obesity  prevalence, 2009 (%)'])/df['Female obesity  prevalence, 2009 (%)'])*100
# Out:
# C:\Users\Bharath\AppData\Local\Temp\ipykernel_18928\1480472217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Female Obesity Increase'] = ((df['Female obesity prevalence, 2011* (%)']-df['Female obesity  prevalence, 2009 (%)'])/df['Female obesity  prevalence, 2009 (%)'])*100

# %%
df
# Out:
#                State  Income 2009  Male obesity prevalence, 2009 (%)  \
# 0            Alabama        40500                               36.1
# 1             Alaska        67000                               32.8
# 2            Arizona        48700                               31.6
# 3           Arkansas        37800                               36.1
# 4         California        58900                               28.7
# 5           Colorado        55400                               25.8
# 6        Connecticut        67000                               29.7
# 7           Delaware        56900                               35.9
# 8            Florida        44700                               33.2
# 9            Georgia        47600                               33.6
# 10            Hawaii        64100                               27.4
# 11             Idaho        44900                               32.8
# 12          Illinois        54000                               32.9
# ...

# %% [markdown]
# Checking the datatypes

# %%
df.dtypes
# Out:
# State                                    object
# Income 2009                               int32
# Male obesity prevalence, 2009 (%)       float64
# Female obesity  prevalence, 2009 (%)    float64
# Income 2011                               int32
# Male obesity  prevalence, 2011* (%)     float64
# Female obesity prevalence, 2011* (%)    float64
# Income Increase                         float64
# Male Obesity Increase                   float64
# Female Obesity Increase                 float64
# dtype: object

# %% [markdown]
# Checking for null values

# %%
df.isna().sum()
# Out:
# State                                   0
# Income 2009                             0
# Male obesity prevalence, 2009 (%)       0
# Female obesity  prevalence, 2009 (%)    0
# Income 2011                             0
# Male obesity  prevalence, 2011* (%)     0
# Female obesity prevalence, 2011* (%)    0
# Income Increase                         0
# Male Obesity Increase                   0
# Female Obesity Increase                 0
# dtype: int64

# %%
df.describe()
# Out:
#         Income 2009  Male obesity prevalence, 2009 (%)  \
# count     51.000000                          51.000000
# mean   50445.098039                          32.962745
# std     8465.206760                           3.108116
# min    36600.000000                          21.600000
# 25%    44800.000000                          31.700000
# 50%    48300.000000                          32.900000
# 75%    55500.000000                          35.150000
# max    69300.000000                          38.200000
#
#        Female obesity  prevalence, 2009 (%)   Income 2011  \
# count                             51.000000     51.000000
# mean                              35.009804  50898.862745
# std                                3.584146   8441.626026
# min                               25.400000  36919.000000
# 25%                               32.450000  44260.500000
# 50%                               34.900000  49392.000000
# ...

# %% [markdown]
# Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['State', 'Income 2009', 'Male obesity prevalence, 2009 (%)',
#        'Female obesity  prevalence, 2009 (%)', 'Income 2011',
#        'Male obesity  prevalence, 2011* (%)',
#        'Female obesity prevalence, 2011* (%)', 'Income Increase',
#        'Male Obesity Increase', 'Female Obesity Increase'],
#       dtype='object')

# %% [markdown]
# Here we display histograms for each column to display the range in which the values are stored in and the frequency of each value.

# %%
fig, axs = plt.subplots(3, 3, figsize=(15, 15))

sns.histplot(data = df['Income 2009'], kde = True, ax=axs[0, 0])
sns.histplot(data = df['Male obesity prevalence, 2009 (%)'], kde = True, ax=axs[0, 1])
sns.histplot(data = df['Female obesity  prevalence, 2009 (%)'], kde = True, ax=axs[0, 2])
sns.histplot(data = df['Income 2011'], kde = True, ax=axs[1, 0])
sns.histplot(data = df['Male obesity  prevalence, 2011* (%)'], kde = True, ax=axs[1, 1])
sns.histplot(data = df['Female obesity prevalence, 2011* (%)'], kde = True, ax=axs[1, 2])
sns.histplot(data = df['Income Increase'], kde = True, ax=axs[2, 0])
sns.histplot(data = df['Male Obesity Increase'], kde = True, ax=axs[2, 1])
sns.histplot(data = df['Female Obesity Increase'], kde = True, ax=axs[2, 2])

plt.show()

# %% [markdown]
# Here we plot the boxplots for each caloumn to check for outliers

# %%
fig, axs = plt.subplots(3, 3, figsize=(15, 15))

p1 = sns.boxplot(data = df['Income 2011'], ax=axs[0, 0])
p2 = sns.boxplot(data = df['Male obesity prevalence, 2009 (%)'], ax=axs[0, 1])
p3 = sns.boxplot(data = df['Female obesity  prevalence, 2009 (%)'], ax=axs[0, 2])
p4 = sns.boxplot(data = df['Income 2009'], ax=axs[1, 0])
p5 = sns.boxplot(data = df['Male obesity  prevalence, 2011* (%)'], ax=axs[1, 1])
p6 = sns.boxplot(data = df['Female obesity prevalence, 2011* (%)'], ax=axs[1, 2])
p7 = sns.boxplot(data = df['Income Increase'], ax=axs[2, 0])
p8 = sns.boxplot(data = df['Male Obesity Increase'],  ax=axs[2, 1])
p9 = sns.boxplot(data = df['Female Obesity Increase'], ax=axs[2, 2])

p1.title.set_text('Income 2011')
p2.title.set_text('Male obesity prevalence, 2009 (%)')
p3.title.set_text('Female obesity prevalence, 2009 (%)')
p4.title.set_text('Income 2009')
p5.title.set_text('Male obesity prevalence, 2011 (%)')
p6.title.set_text('Female obesity prevalence, 2011 (%)')
p7.title.set_text('Income Increase')
p8.title.set_text('Male Obesity Increase')
p9.title.set_text('Female Obesity Increase')

plt.show()

# %% [markdown]
# Displot showing the clustering of male obesity in 2009 vs income in 2009

# %%
sns.displot(x=df['Income 2009'], y=df['Male obesity prevalence, 2009 (%)'],  data=df)
plt.title('Income vs Male Obesity (2009)', fontsize=18)
plt.xlabel('Income', fontsize=16)
plt.ylabel('Obesity', fontsize=16)
# Out:
# Text(0.42499999999999716, 0.5, 'Obesity')

# %% [markdown]
# Displot showing the clustering of male obesity in 2011 vs income in 2011

# %%
sns.displot(x=df['Income 2011'], y=df['Male obesity  prevalence, 2011* (%)'],  data=df)
plt.title('Income vs Male Obesity (2011)', fontsize=18)
plt.xlabel('Income', fontsize=16)
plt.ylabel('Obesity', fontsize=16)
# Out:
# Text(0.42499999999999716, 0.5, 'Obesity')

# %% [markdown]
# Displot showing the clustering of Female obesity in 2009 vs income in 2009

# %%
sns.displot(x=df['Income 2009'], y=df['Female obesity  prevalence, 2009 (%)'],  data=df, color='red')
plt.title('Income vs Female Obesity (2009)', fontsize=18)
plt.xlabel('Income', fontsize=16)
plt.ylabel('Obesity', fontsize=16)
# Out:
# Text(0.42499999999999716, 0.5, 'Obesity')

# %% [markdown]
# Displot showing the clustering of Female obesity in 2011 vs income in 2011

# %%
sns.displot(x=df['Income 2009'], y=df['Female obesity prevalence, 2011* (%)'],  data=df, color='red')
plt.title('Income vs Female Obesity (2009)', fontsize=18)
plt.xlabel('Income', fontsize=16)
plt.ylabel('Obesity', fontsize=16)
# Out:
# Text(0.42499999999999716, 0.5, 'Obesity')

# %%
t = df.sort_values('Income 2009')

# %% [markdown]
# Barplot describing the statewise income in 2009

# %%
plt.figure(figsize=(15,10))
plt.title('State vs Income (2009)')
plt.xticks(rotation=90)
sns.barplot(x=t['State'],y=t['Income 2009'],data=t)
# Out:
# <AxesSubplot:title={'center':'State vs Income (2009)'}, xlabel='State', ylabel='Income 2009'>

# %%
t1 = df.sort_values('Income 2011',ascending=False)

# %% [markdown]
# Barplot describing the statewise income in 2011

# %%
plt.figure(figsize=(15,10))
plt.title('State vs Income (2011)')
plt.xticks(rotation=90)
sns.barplot(x=t1['State'],y=t1['Income 2011'],data=t1)
# Out:
# <AxesSubplot:title={'center':'State vs Income (2011)'}, xlabel='State', ylabel='Income 2011'>

# %%
t2 = df.sort_values('Male obesity prevalence, 2009 (%)')
t3 = df.sort_values('Female obesity  prevalence, 2009 (%)')

# %% [markdown]
# Lineplot showing the Prevalence of obesity in men for the year 2009 (Statewise)

# %%
plt.figure(figsize=(15,10))
plt.title('State vs Male Obesity (2009)')
plt.xticks(rotation=90)
sns.lineplot(x=t2['State'],y=t2['Male obesity prevalence, 2009 (%)'],data=t2)
# Out:
# <AxesSubplot:title={'center':'State vs Male Obesity (2009)'}, xlabel='State', ylabel='Male obesity prevalence, 2009 (%)'>

# %% [markdown]
# Lineplot showing the Prevalence of obesity in women for the year 2009 (Statewise)

# %%
plt.figure(figsize=(15,10))
plt.title('State vs Female Obesity (2009)')
plt.xticks(rotation=90)
sns.lineplot(x=t3['State'],y=t3['Female obesity  prevalence, 2009 (%)'],data=t3)
# Out:
# <AxesSubplot:title={'center':'State vs Female Obesity (2009)'}, xlabel='State', ylabel='Female obesity  prevalence, 2009 (%)'>

# %%
t4 = df.sort_values('Male obesity  prevalence, 2011* (%)')
t5 = df.sort_values('Female obesity prevalence, 2011* (%)')

# %% [markdown]
# Lineplot showing the statewise Prevalence of obesity in men for the year 2011

# %%
plt.figure(figsize=(15,10))
plt.title('State vs Male Obesity (2011)')
plt.xticks(rotation=90)
sns.lineplot(x=t4['State'],y=t4['Male obesity  prevalence, 2011* (%)'],data=t4)
# Out:
# <AxesSubplot:title={'center':'State vs Male Obesity (2011)'}, xlabel='State', ylabel='Male obesity  prevalence, 2011* (%)'>

# %% [markdown]
# Lineplot showing the statewise Prevalence of obesity in women for the year 2011

# %%
plt.figure(figsize=(15,10))
plt.title('State vs Female Obesity (2011)')
plt.xticks(rotation=90)
sns.lineplot(x=t5['State'],y=t5['Female obesity prevalence, 2011* (%)'],data=t5)
# Out:
# <AxesSubplot:title={'center':'State vs Female Obesity (2011)'}, xlabel='State', ylabel='Female obesity prevalence, 2011* (%)'>

# %% [markdown]
# 2 Lineplots showing the statewise difference in income for the years 2009 and 2011

# %%
plt.figure(figsize=(15,10))
plt.title('State vs Income (2009 & 2011)')
plt.xticks(rotation=90)
sns.lineplot(x=t['State'],y=t['Income 2009'],data=t)
sns.lineplot(x=t['State'],y=t['Income 2011'],data=t, color='orange')
plt.legend(['2009','2011'],loc ="upper left")

# %% [markdown]
# Lineplots showing the difference in prevalence of obesity in men for the year 2009 and 2011

# %%
plt.figure(figsize=(15,10))
plt.title('State vs Male Obesity (2009 & 2011)')
plt.xticks(rotation=90)
sns.lineplot(x=t2['State'],y=t2['Male obesity prevalence, 2009 (%)'],data=t2)
sns.lineplot(x=t2['State'],y=t2['Male obesity  prevalence, 2011* (%)'],data=t2, color='orange')
plt.legend(['2009','2011'],loc ="upper left")

# %% [markdown]
# Lineplots showing the difference in prevalence of obesity in women for the year 2009 and 2011

# %%
plt.figure(figsize=(15,10))
plt.title('State vs Female Obesity (2009 & 2011)')
plt.xticks(rotation=90)
sns.lineplot(x=t3['State'],y=t3['Female obesity  prevalence, 2009 (%)'],data=t3)
sns.lineplot(x=t3['State'],y=t3['Female obesity prevalence, 2011* (%)'],data=t3, color='orange')
plt.legend(['2009','2011'],loc ="upper left")

# %%
t6 = df.sort_values('Income Increase')

# %% [markdown]
# Barplot showing the change in income for the states from 2009 to 2011

# %%
plt.figure(figsize=(15,10))
plt.title('State vs Income Increase')
plt.xticks(rotation=90)
sns.barplot(x=t6['State'],y=t6['Income Increase'],data=t6)
# Out:
# <AxesSubplot:title={'center':'State vs Income Increase'}, xlabel='State', ylabel='Income Increase'>

# %%
t7 = df.sort_values('Male Obesity Increase')
t8 = df.sort_values('Female Obesity Increase')

# %% [markdown]
# Barplot showing the change in prevalence of obesity in men for the states from 2009 to 2011

# %%
plt.figure(figsize=(15,5))
plt.title('State vs male Obesity Increase')
plt.xticks(rotation=90)
sns.barplot(x=t7['State'],y=t7['Male Obesity Increase'],data=t7)
# Out:
# <AxesSubplot:title={'center':'State vs male Obesity Increase'}, xlabel='State', ylabel='Male Obesity Increase'>

# %% [markdown]
# Barplot showing the change in prevalence of obesity in women for the states from 2009 to 2011

# %%
plt.figure(figsize=(15,5))
plt.title('State vs Female Obesity Increase')
plt.xticks(rotation=90)
sns.barplot(x=t8['State'],y=t8['Female Obesity Increase'],data=t8)
# Out:
# <AxesSubplot:title={'center':'State vs Female Obesity Increase'}, xlabel='State', ylabel='Female Obesity Increase'>

# %%
df.columns
# Out:
# Index(['State', 'Income 2009', 'Male obesity prevalence, 2009 (%)',
#        'Female obesity  prevalence, 2009 (%)', 'Income 2011',
#        'Male obesity  prevalence, 2011* (%)',
#        'Female obesity prevalence, 2011* (%)', 'Income Increase',
#        'Male Obesity Increase', 'Female Obesity Increase'],
#       dtype='object')

# %% [markdown]
# Scatter plots showing the relation between income and obesity in men and women for the years 2009 and 2011

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))

p1=sns.scatterplot(x=df['Income 2009'], y=df['Male obesity prevalence, 2009 (%)'],  data=df, ax=axs[0, 0])
p2=sns.scatterplot(x=df['Income 2011'], y=df['Male obesity  prevalence, 2011* (%)'],  data=df, ax=axs[0, 1])
p3=sns.scatterplot(x=df['Income 2009'], y=df['Female obesity  prevalence, 2009 (%)'],  data=df, color='red', ax=axs[1, 0])
p4=sns.scatterplot(x=df['Income 2009'], y=df['Female obesity prevalence, 2011* (%)'],  data=df, color='red', ax=axs[1, 1])


p1.title.set_text('Income vs Male Obesity (2009)')
p2.title.set_text('Income vs Male Obesity (2011)')
p3.title.set_text('Income vs Female Obesity (2009)')
p4.title.set_text('Income vs Female Obesity (2009)')

plt.show()

# %% [markdown]
# The plots confirm our assumption that income is negatively correlated to obesity. That is, states with a lower average income have higher rates of obesity.

# %%
temp = df[['Male obesity prevalence, 2009 (%)','Female obesity  prevalence, 2009 (%)','Male obesity  prevalence, 2011* (%)','Female obesity prevalence, 2011* (%)','Income 2009','Income 2011']]

# %% [markdown]
# Correlation Matrix showing the relation among the columns in our dataframe

# %%
sns.set(rc= {'figure.figsize':(15,8)})
sns.heatmap(temp.corr(),annot=True,cmap='Reds')
plt.title('Correlation')
# Out:
# Text(0.5, 1.0, 'Correlation')

# %% [markdown]
# Pairplot to display the relation between the columns.

# %%
plt.figure(figsize=(20,20))

sns.pairplot(data = temp)

# %% [markdown]
# Conclusion
#
# 1. We performed analysis on each column in our dataframe.
#
# 2. We found a negative correlation between income and prevalence of obesity in the United States. This mean states with higher levels of income tend to have lower levels of obesity.
#
# 3. There is also a possitive correlation between the income values for the years 2009 and 2011 and similarly the prevalnce of obesity among men and women for the years 2009 and 2011, showing a steading increase in the average salaries as well as prevalence of obesity for each state.
